# %% [markdown]
# WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the units to "imperial"
units = "metric"

# Set the API base URL with units parameter
base_url = f"http://api.openweathermap.org/data/2.5/weather?units={units}&"

# Create a list to store city data
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city and API key
    city_url = f"{base_url}q={city}&appid={weather_api_key}"

    # Log the record and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Increment the record count
    record_count += 1

    # Run an API request for each city
    try:
        # Send API request and get response
        response = requests.get(city_url)
        response.raise_for_status() # Check for any errors in the response

        city_weather = response.json()

        # latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print(f"City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tura
# Processing Record 2 of Set 1 | altai
# Processing Record 3 of Set 1 | sitka
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | mili
# Processing Record 7 of Set 1 | ebon
# Processing Record 8 of Set 1 | iskateley
# Processing Record 9 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | kushiro
# Processing Record 13 of Set 1 | vorgashor
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | akureyri
# Processing Record 17 of Set 1 | shortandy
# Processing Record 18 of Set 1 | west island
# Processing Record 19 of Set 1 | ketchikan
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | puerto natales
# Processing Record 22 of Set 1 | isafjordur
# Processing Record 23 of Set 1 | nemuro
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | xilin hot
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | china
# Processing Record 30 of Set 1 | nadvoitsy
# Processing Record 31 of Set 1 | berovo
# Processing Record 32 of Set 1 | udachny
# Processing Record 33 of Set 1 | qamdo
# Processing Record 34 of Set 1 | crane
# Processing Record 35 of Set 1 | stanley
# Processing Record 36 of Set 1 | garissa
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | waitangi
# Processing Record 39 of Set 1 | untergriesbach
# Processing Record 40 of Set 1 | dade city
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | cockburn town
# Processing Record 43 of Set 1 | port-aux-francais
# Processing Record 44 of Set 1 | richards bay
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# Processing Record 46 of Set 1 | wangqing
# Processing Record 47 of Set 1 | haiku-pauwela
# Processing Record 48 of Set 1 | timizart
# Processing Record 49 of Set 1 | arkalyk
# Processing Record 50 of Set 1 | newman
# Processing Record 0 of Set 2 | as salt
# Processing Record 1 of Set 2 | papao
# Processing Record 2 of Set 2 | utrik
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | saipan
# Processing Record 5 of Set 2 | klyuchi
# Processing Record 6 of Set 2 | kidal
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | kourou
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | dunay
# Processing Record 11 of Set 2 | wailua homesteads
# Processing Record 12 of Set 2 | zemio
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | kailua-kona
# Processing Record 15 of Set 2 | mayma
# Processing Record 16 of Set 2 | bonny
# Processing Record 17 of Set 2 | selfoss
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | verkhnevilyuysk
# Processing Record 20 of Set 2 | markovo
# Processing Record 21 of Set 2 | mantua
# Processing Record 22 of Set 2 | moree
# Processing Record 23 of Set 2 | tukrah
# Processing Record 24 of Set 2 | mong cai
# City not found. Skipping...
# Processing Record 25 of Set 2 | tangara
# Processing Record 26 of Set 2 | sevastopol
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | saint-francois
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | kabompo
# Processing Record 31 of Set 2 | college
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | constantia
# Processing Record 34 of Set 2 | adamstown
# Processing Record 35 of Set 2 | lihue
# Processing Record 36 of Set 2 | invercargill
# Processing Record 37 of Set 2 | ta`u
# Processing Record 38 of Set 2 | luba
# Processing Record 39 of Set 2 | la passe
# Processing Record 40 of Set 2 | nova xavantina
# Processing Record 41 of Set 2 | fale old settlement
# Processing Record 42 of Set 2 | de aar
# Processing Record 43 of Set 2 | micheweni
# Processing Record 44 of Set 2 | smolyan
# Processing Record 45 of Set 2 | sinabang
# Processing Record 46 of Set 2 | qaqortoq
# Processing Record 47 of Set 2 | pyt-yakh
# Processing Record 48 of Set 2 | enewetak
# Processing Record 49 of Set 2 | imperatriz
# Processing Record 0 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 1 of Set 3 | fada
# Processing Record 2 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 3 of Set 3 | alpena
# Processing Record 4 of Set 3 | hawaiian paradise park
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | plastun
# Processing Record 9 of Set 3 | iquique
# Processing Record 10 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 11 of Set 3 | whitehorse
# Processing Record 12 of Set 3 | ad dilam
# Processing Record 13 of Set 3 | mazamari
# Processing Record 14 of Set 3 | margaret river
# Processing Record 15 of Set 3 | bardai
# Processing Record 16 of Set 3 | puerto baquerizo moreno
# Processing Record 17 of Set 3 | bilibino
# Processing Record 18 of Set 3 | alofi
# Processing Record 19 of Set 3 | novyy urengoy
# Processing Record 20 of Set 3 | bayanhongor
# Processing Record 21 of Set 3 | vilyuysk
# Processing Record 22 of Set 3 | okhotsk
# Processing Record 23 of Set 3 | flekkefjord
# Processing Record 24 of Set 3 | port mathurin
# Processing Record 25 of Set 3 | rexburg
# Processing Record 26 of Set 3 | usogorsk
# Processing Record 27 of Set 3 | olonkinbyen
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | daru
# Processing Record 30 of Set 3 | jutai
# Processing Record 31 of Set 3 | aasiaat
# Processing Record 32 of Set 3 | chonchi
# Processing Record 33 of Set 3 | susuman
# Processing Record 34 of Set 3 | bushehr
# Processing Record 35 of Set 3 | smithers
# Processing Record 36 of Set 3 | molde
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | gornopravdinsk
# Processing Record 39 of Set 3 | egilsstadir
# Processing Record 40 of Set 3 | nabire
# Processing Record 41 of Set 3 | noumea
# Processing Record 42 of Set 3 | chibougamau
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | banyo
# Processing Record 45 of Set 3 | mombetsu
# Processing Record 46 of Set 3 | rapla
# Processing Record 47 of Set 3 | dudinka
# Processing Record 48 of Set 3 | akdepe
# Processing Record 49 of Set 3 | pangoa
# Processing Record 0 of Set 4 | oleshky
# Processing Record 1 of Set 4 | macapa
# Processing Record 2 of Set 4 | hithadhoo
# Processing Record 3 of Set 4 | rabo de peixe
# Processing Record 4 of Set 4 | afaahiti
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | fortaleza
# Processing Record 7 of Set 4 | broome
# Processing Record 8 of Set 4 | namibe
# Processing Record 9 of Set 4 | borovskoy
# Processing Record 10 of Set 4 | waingapu
# Processing Record 11 of Set 4 | farafangana
# Processing Record 12 of Set 4 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 13 of Set 4 | tsiombe
# Processing Record 14 of Set 4 | walvis bay
# Processing Record 15 of Set 4 | puerto santa
# Processing Record 16 of Set 4 | pandan
# Processing Record 17 of Set 4 | severo-yeniseyskiy
# Processing Record 18 of Set 4 | magadan
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | narsimhapur
# Processing Record 21 of Set 4 | tolanaro
# Processing Record 22 of Set 4 | st. john's
# Processing Record 23 of Set 4 | pingliang
# Processing Record 24 of Set 4 | kolonia town
# Processing Record 25 of Set 4 | hadibu
# Processing Record 26 of Set 4 | timimoun
# Processing Record 27 of Set 4 | santa cruz
# Processing Record 28 of Set 4 | kerouane
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | kissidougou
# Processing Record 31 of Set 4 | banda aceh
# Processing Record 32 of Set 4 | kwale
# Processing Record 33 of Set 4 | novaya igirma
# Processing Record 34 of Set 4 | colonia
# Processing Record 35 of Set 4 | hermanus
# Processing Record 36 of Set 4 | puerto aysen
# Processing Record 37 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 4 | kapuskasing
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | quesnel
# Processing Record 42 of Set 4 | galliano
# Processing Record 43 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 44 of Set 4 | alice springs
# Processing Record 45 of Set 4 | rouyn-noranda
# Processing Record 46 of Set 4 | poronaysk
# Processing Record 47 of Set 4 | kiunga
# Processing Record 48 of Set 4 | isle of lewis
# City not found. Skipping...
# Processing Record 49 of Set 4 | dwarka
# Processing Record 0 of Set 5 | uturoa
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | fort bragg
# Processing Record 3 of Set 5 | ilhabela
# Processing Record 4 of Set 5 | san rafael
# Processing Record 5 of Set 5 | kalianget
# Processing Record 6 of Set 5 | margate
# Processing Record 7 of Set 5 | mathba
# Processing Record 8 of Set 5 | bubaque
# Processing Record 9 of Set 5 | vernon
# Processing Record 10 of Set 5 | tazacorte
# Processing Record 11 of Set 5 | andrews
# Processing Record 12 of Set 5 | acarau
# Processing Record 13 of Set 5 | el alto
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | tarawa
# Processing Record 16 of Set 5 | flying fish cove
# Processing Record 17 of Set 5 | keren
# Processing Record 18 of Set 5 | kralendijk
# Processing Record 19 of Set 5 | kerikeri
# Processing Record 20 of Set 5 | mahibadhoo
# Processing Record 21 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 22 of Set 5 | papatowai
# Processing Record 23 of Set 5 | feraoun
# Processing Record 24 of Set 5 | balarampur
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | coahuayana de hidalgo
# Processing Record 27 of Set 5 | xinmin
# Processing Record 28 of Set 5 | san patricio
# Processing Record 29 of Set 5 | tralee
# Processing Record 30 of Set 5 | formosa do rio preto
# Processing Record 31 of Set 5 | road town
# Processing Record 32 of Set 5 | nuku'alofa
# Processing Record 33 of Set 5 | talcahuano
# Processing Record 34 of Set 5 | geraldton
# Processing Record 35 of Set 5 | abadeh
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | gunjur
# Processing Record 38 of Set 5 | kingston
# Processing Record 39 of Set 5 | brokopondo
# Processing Record 40 of Set 5 | axim
# Processing Record 41 of Set 5 | nyala
# Processing Record 42 of Set 5 | remire-montjoly
# Processing Record 43 of Set 5 | riversdale
# Processing Record 44 of Set 5 | fort st. john
# Processing Record 45 of Set 5 | pimentel
# Processing Record 46 of Set 5 | xique xique
# Processing Record 47 of Set 5 | laguna
# Processing Record 48 of Set 5 | olgii
# City not found. Skipping...
# Processing Record 49 of Set 5 | laojunmiao
# Processing Record 0 of Set 6 | eregli
# Processing Record 1 of Set 6 | coquimbo
# Processing Record 2 of Set 6 | suzhou
# Processing Record 3 of Set 6 | mme-bafumen
# Processing Record 4 of Set 6 | joshimath
# Processing Record 5 of Set 6 | merizo village
# Processing Record 6 of Set 6 | atafu village
# Processing Record 7 of Set 6 | kirakira
# Processing Record 8 of Set 6 | tal'menka
# Processing Record 9 of Set 6 | west mackay
# Processing Record 10 of Set 6 | labrador city
# Processing Record 11 of Set 6 | meru
# Processing Record 12 of Set 6 | cole harbour
# Processing Record 13 of Set 6 | tual
# Processing Record 14 of Set 6 | lepsy
# Processing Record 15 of Set 6 | east end
# Processing Record 16 of Set 6 | tieling
# Processing Record 17 of Set 6 | kribi
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | lerwick
# Processing Record 20 of Set 6 | usinsk
# Processing Record 21 of Set 6 | pacific grove
# Processing Record 22 of Set 6 | kutum
# Processing Record 23 of Set 6 | gamba
# Processing Record 24 of Set 6 | bahla'
# City not found. Skipping...
# Processing Record 25 of Set 6 | xuddur
# Processing Record 26 of Set 6 | as saff
# Processing Record 27 of Set 6 | betio village
# Processing Record 28 of Set 6 | carbonear
# Processing Record 29 of Set 6 | gondar
# Processing Record 30 of Set 6 | issia
# Processing Record 31 of Set 6 | dawei
# Processing Record 32 of Set 6 | island harbour
# Processing Record 33 of Set 6 | turkeli
# Processing Record 34 of Set 6 | igreja
# Processing Record 35 of Set 6 | el calafate
# Processing Record 36 of Set 6 | dumingag
# Processing Record 37 of Set 6 | temiskaming shores
# Processing Record 38 of Set 6 | uchiza
# Processing Record 39 of Set 6 | melfort
# Processing Record 40 of Set 6 | altay
# Processing Record 41 of Set 6 | namdrik
# Processing Record 42 of Set 6 | howrah
# Processing Record 43 of Set 6 | lambarene
# Processing Record 44 of Set 6 | buka
# Processing Record 45 of Set 6 | sabang
# Processing Record 46 of Set 6 | ust'-kut
# Processing Record 47 of Set 6 | cangucu
# Processing Record 48 of Set 6 | tazovsky
# Processing Record 49 of Set 6 | mashhad
# Processing Record 0 of Set 7 | bharthana
# Processing Record 1 of Set 7 | benghazi
# Processing Record 2 of Set 7 | kijang
# Processing Record 3 of Set 7 | arcachon
# Processing Record 4 of Set 7 | nova vicosa
# Processing Record 5 of Set 7 | suez
# Processing Record 6 of Set 7 | kupang
# Processing Record 7 of Set 7 | pontes e lacerda
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | ust-nera
# Processing Record 10 of Set 7 | nar'yan-mar
# Processing Record 11 of Set 7 | thinadhoo
# Processing Record 12 of Set 7 | motueka
# Processing Record 13 of Set 7 | mejit
# Processing Record 14 of Set 7 | kibale
# Processing Record 15 of Set 7 | klaksvik
# Processing Record 16 of Set 7 | talakan
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | polyarnyy
# Processing Record 19 of Set 7 | lokken
# City not found. Skipping...
# Processing Record 20 of Set 7 | kuta
# Processing Record 21 of Set 7 | san isidro de curuguaty
# Processing Record 22 of Set 7 | phan rang-thap cham
# Processing Record 23 of Set 7 | taksimo
# Processing Record 24 of Set 7 | fonte boa
# Processing Record 25 of Set 7 | palikir - national government center
# Processing Record 26 of Set 7 | cidreira
# Processing Record 27 of Set 7 | pasto
# Processing Record 28 of Set 7 | petauke
# Processing Record 29 of Set 7 | wagar
# Processing Record 30 of Set 7 | faaborg
# Processing Record 31 of Set 7 | bokoro
# Processing Record 32 of Set 7 | bemidji
# Processing Record 33 of Set 7 | bakchar
# Processing Record 34 of Set 7 | plettenberg bay
# Processing Record 35 of Set 7 | toledo
# Processing Record 36 of Set 7 | porto novo
# Processing Record 37 of Set 7 | shubarshi
# Processing Record 38 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 39 of Set 7 | santo antonio
# Processing Record 40 of Set 7 | talnakh
# Processing Record 41 of Set 7 | nyurba
# Processing Record 42 of Set 7 | puerto lopez
# Processing Record 43 of Set 7 | goundi
# Processing Record 44 of Set 7 | gaalkacyo
# Processing Record 45 of Set 7 | bagong pagasa
# Processing Record 46 of Set 7 | tibiri
# Processing Record 47 of Set 7 | diego martin
# Processing Record 48 of Set 7 | fort wellington
# Processing Record 49 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 0 of Set 8 | tutoia
# Processing Record 1 of Set 8 | nepomuceno
# Processing Record 2 of Set 8 | tanabe
# Processing Record 3 of Set 8 | gadzhiyevo
# Processing Record 4 of Set 8 | quiberon
# Processing Record 5 of Set 8 | taperoa
# Processing Record 6 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 8 | taltal
# Processing Record 8 of Set 8 | yagry
# City not found. Skipping...
# Processing Record 9 of Set 8 | murray bridge
# Processing Record 10 of Set 8 | yermakovskoye
# Processing Record 11 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 8 | al burayqah
# Processing Record 13 of Set 8 | floro
# Processing Record 14 of Set 8 | port isabel
# Processing Record 15 of Set 8 | vilyuchinsk
# Processing Record 16 of Set 8 | ouellah
# City not found. Skipping...
# Processing Record 17 of Set 8 | prado
# Processing Record 18 of Set 8 | puli
# Processing Record 19 of Set 8 | shahriar
# Processing Record 20 of Set 8 | nebraska city
# Processing Record 21 of Set 8 | we
# City not found. Skipping...
# Processing Record 22 of Set 8 | lieksa
# Processing Record 23 of Set 8 | weno
# Processing Record 24 of Set 8 | barra de santo antonio
# Processing Record 25 of Set 8 | trou du nord
# Processing Record 26 of Set 8 | pama
# Processing Record 27 of Set 8 | saint-joseph
# Processing Record 28 of Set 8 | rio gallegos
# Processing Record 29 of Set 8 | nueva gerona
# Processing Record 30 of Set 8 | salalah
# Processing Record 31 of Set 8 | hammerfest
# Processing Record 32 of Set 8 | ahar
# Processing Record 33 of Set 8 | sao gabriel da cachoeira
# Processing Record 34 of Set 8 | paracatu
# Processing Record 35 of Set 8 | kuanda
# Processing Record 36 of Set 8 | pont rouge
# Processing Record 37 of Set 8 | san julian
# Processing Record 38 of Set 8 | boguchany
# Processing Record 39 of Set 8 | pocito
# Processing Record 40 of Set 8 | sakata
# Processing Record 41 of Set 8 | fenoarivo be
# Processing Record 42 of Set 8 | inirida
# Processing Record 43 of Set 8 | buala
# Processing Record 44 of Set 8 | kavaratti
# Processing Record 45 of Set 8 | lebu
# Processing Record 46 of Set 8 | oranjemund
# Processing Record 47 of Set 8 | minas de marcona
# Processing Record 48 of Set 8 | champerico
# Processing Record 49 of Set 8 | masterton
# Processing Record 0 of Set 9 | buri ram
# Processing Record 1 of Set 9 | el granada
# Processing Record 2 of Set 9 | palapye
# Processing Record 3 of Set 9 | zdvinsk
# Processing Record 4 of Set 9 | port alfred
# Processing Record 5 of Set 9 | ar ruways
# Processing Record 6 of Set 9 | ixtapa
# Processing Record 7 of Set 9 | ha'il
# Processing Record 8 of Set 9 | port augusta
# Processing Record 9 of Set 9 | khanty-mansiysk
# Processing Record 10 of Set 9 | burang
# Processing Record 11 of Set 9 | chipata
# Processing Record 12 of Set 9 | wanxian
# Processing Record 13 of Set 9 | pathein
# Processing Record 14 of Set 9 | yeraliyev
# Processing Record 15 of Set 9 | tefe
# Processing Record 16 of Set 9 | santana
# Processing Record 17 of Set 9 | salekhard
# Processing Record 18 of Set 9 | bellmere
# Processing Record 19 of Set 9 | severnoye
# Processing Record 20 of Set 9 | barcelos
# Processing Record 21 of Set 9 | ola
# Processing Record 22 of Set 9 | paradera
# City not found. Skipping...
# Processing Record 23 of Set 9 | aromashevo
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | kristiansund
# Processing Record 26 of Set 9 | bamboo flat
# Processing Record 27 of Set 9 | sandnessjoen
# Processing Record 28 of Set 9 | sirre
# Processing Record 29 of Set 9 | point pleasant
# Processing Record 30 of Set 9 | tongliao
# Processing Record 31 of Set 9 | selkirk
# Processing Record 32 of Set 9 | panaba
# Processing Record 33 of Set 9 | piti village
# Processing Record 34 of Set 9 | northam
# Processing Record 35 of Set 9 | arno
# Processing Record 36 of Set 9 | karratha
# Processing Record 37 of Set 9 | satuek
# Processing Record 38 of Set 9 | pedro juan caballero
# Processing Record 39 of Set 9 | pisco
# Processing Record 40 of Set 9 | balkanabat
# Processing Record 41 of Set 9 | merritt
# Processing Record 42 of Set 9 | portland
# Processing Record 43 of Set 9 | adrar
# Processing Record 44 of Set 9 | morristown
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | mukalla
# Processing Record 47 of Set 9 | praia da vitoria
# Processing Record 48 of Set 9 | olovyannaya
# Processing Record 49 of Set 9 | noosa heads
# Processing Record 0 of Set 10 | al-`ula
# City not found. Skipping...
# Processing Record 1 of Set 10 | kununurra
# Processing Record 2 of Set 10 | verneuil-sur-avre
# Processing Record 3 of Set 10 | rosarito
# Processing Record 4 of Set 10 | port-vila
# Processing Record 5 of Set 10 | barra do garcas
# Processing Record 6 of Set 10 | atar
# Processing Record 7 of Set 10 | hola
# Processing Record 8 of Set 10 | bel ombre
# Processing Record 9 of Set 10 | vranje
# Processing Record 10 of Set 10 | scarborough
# Processing Record 11 of Set 10 | trenggalek
# Processing Record 12 of Set 10 | progreso
# Processing Record 13 of Set 10 | lazaro cardenas
# Processing Record 14 of Set 10 | kenai
# Processing Record 15 of Set 10 | quelimane
# Processing Record 16 of Set 10 | fannuj
# City not found. Skipping...
# Processing Record 17 of Set 10 | tshikapa
# Processing Record 18 of Set 10 | blitar
# Processing Record 19 of Set 10 | el hajeb
# Processing Record 20 of Set 10 | aykhal
# Processing Record 21 of Set 10 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 22 of Set 10 | prokhladnyy
# Processing Record 23 of Set 10 | gizo
# Processing Record 24 of Set 10 | kovel
# Processing Record 25 of Set 10 | tofol
# Processing Record 26 of Set 10 | rongelap
# Processing Record 27 of Set 10 | new plymouth
# Processing Record 28 of Set 10 | strezhevoy
# Processing Record 29 of Set 10 | yibin
# Processing Record 30 of Set 10 | vadso
# Processing Record 31 of Set 10 | inhambane
# Processing Record 32 of Set 10 | mount pearl
# Processing Record 33 of Set 10 | conception bay south
# Processing Record 34 of Set 10 | north shore
# Processing Record 35 of Set 10 | shakhun'ya
# Processing Record 36 of Set 10 | dakhla
# Processing Record 37 of Set 10 | mairena del aljarafe
# Processing Record 38 of Set 10 | tateyama
# Processing Record 39 of Set 10 | eydhafushi
# Processing Record 40 of Set 10 | amga
# Processing Record 41 of Set 10 | port douglas
# Processing Record 42 of Set 10 | toliara
# Processing Record 43 of Set 10 | salinopolis
# Processing Record 44 of Set 10 | tamanrasset
# Processing Record 45 of Set 10 | vershino-darasunskiy
# Processing Record 46 of Set 10 | nueva palestina
# Processing Record 47 of Set 10 | cidade velha
# Processing Record 48 of Set 10 | badger
# Processing Record 49 of Set 10 | daura
# Processing Record 0 of Set 11 | manismata
# Processing Record 1 of Set 11 | ponta delgada
# Processing Record 2 of Set 11 | lisakovsk
# Processing Record 3 of Set 11 | metlili chaamba
# Processing Record 4 of Set 11 | auki
# Processing Record 5 of Set 11 | tomatlan
# Processing Record 6 of Set 11 | borogontsy
# Processing Record 7 of Set 11 | novospasskoye
# Processing Record 8 of Set 11 | yanchep
# Processing Record 9 of Set 11 | quang ngai
# Processing Record 10 of Set 11 | cedeira
# Processing Record 11 of Set 11 | formosa
# Processing Record 12 of Set 11 | puerto carreno
# Processing Record 13 of Set 11 | banes
# Processing Record 14 of Set 11 | venev
# Processing Record 15 of Set 11 | bhimunipatnam
# Processing Record 16 of Set 11 | whangarei
# Processing Record 17 of Set 11 | tidaholm
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | banjarmasin
# Processing Record 20 of Set 11 | toccoa
# Processing Record 21 of Set 11 | saminaka
# Processing Record 22 of Set 11 | haldibari
# Processing Record 23 of Set 11 | maiwut
# City not found. Skipping...
# Processing Record 24 of Set 11 | argo
# Processing Record 25 of Set 11 | villa gesell
# Processing Record 26 of Set 11 | oqtosh
# Processing Record 27 of Set 11 | shofirkon shahri
# City not found. Skipping...
# Processing Record 28 of Set 11 | mariinsk
# Processing Record 29 of Set 11 | myeik
# Processing Record 30 of Set 11 | montpelier
# Processing Record 31 of Set 11 | necochea
# Processing Record 32 of Set 11 | taoudenni
# Processing Record 33 of Set 11 | caleta de carquin
# Processing Record 34 of Set 11 | kayangel
# Processing Record 35 of Set 11 | inonu
# Processing Record 36 of Set 11 | uige
# Processing Record 37 of Set 11 | tibati
# Processing Record 38 of Set 11 | kirensk
# Processing Record 39 of Set 11 | junin de los andes
# Processing Record 40 of Set 11 | labytnangi
# Processing Record 41 of Set 11 | beaufort west
# Processing Record 42 of Set 11 | forster
# Processing Record 43 of Set 11 | soderhamn
# Processing Record 44 of Set 11 | playas
# Processing Record 45 of Set 11 | solok
# Processing Record 46 of Set 11 | mossel bay
# Processing Record 47 of Set 11 | kenora
# Processing Record 48 of Set 11 | parabel'
# Processing Record 49 of Set 11 | vorkuta
# Processing Record 0 of Set 12 | ust'-kulom
# Processing Record 1 of Set 12 | bandarbeyla
# Processing Record 2 of Set 12 | esmeraldas
# Processing Record 3 of Set 12 | khandyga
# Processing Record 4 of Set 12 | la sarre
# Processing Record 5 of Set 12 | revda
# Processing Record 6 of Set 12 | hotan
# Processing Record 7 of Set 12 | aral
# Processing Record 8 of Set 12 | ijuw
# City not found. Skipping...
# Processing Record 9 of Set 12 | sakakah
# Processing Record 10 of Set 12 | galdar
# Processing Record 11 of Set 12 | hondomachi-hondo
# Processing Record 12 of Set 12 | arawa
# Processing Record 13 of Set 12 | vallenar
# Processing Record 14 of Set 12 | kone
# Processing Record 15 of Set 12 | luderitz
# Processing Record 16 of Set 12 | maintirano
# Processing Record 17 of Set 12 | kingscliff
# Processing Record 18 of Set 12 | betioky
# Processing Record 19 of Set 12 | keflavik
# Processing Record 20 of Set 12 | copala
# Processing Record 21 of Set 12 | baiao
# Processing Record 22 of Set 12 | paros
# Processing Record 23 of Set 12 | tongren
# Processing Record 24 of Set 12 | devrek
# Processing Record 25 of Set 12 | sogndal
# Processing Record 26 of Set 12 | mhamid
# Processing Record 27 of Set 12 | zyrya
# Processing Record 28 of Set 12 | makoua
# Processing Record 29 of Set 12 | urumqi
# Processing Record 30 of Set 12 | ceeldheer
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | senanga
# Processing Record 33 of Set 12 | leisure city
# Processing Record 34 of Set 12 | ust-tsilma
# Processing Record 35 of Set 12 | puerto san jose
# Processing Record 36 of Set 12 | mar del plata
# Processing Record 37 of Set 12 | sur
# Processing Record 38 of Set 12 | tiassale
# Processing Record 39 of Set 12 | pontianak
# Processing Record 40 of Set 12 | igarka
# Processing Record 41 of Set 12 | campo grande
# Processing Record 42 of Set 12 | saint-paul
# Processing Record 43 of Set 12 | annau
# Processing Record 44 of Set 12 | mogocha
# Processing Record 45 of Set 12 | colares
# Processing Record 46 of Set 12 | saudarkrokur
# Processing Record 47 of Set 12 | san antonio de pale
# City not found. Skipping...
# Processing Record 48 of Set 12 | birmitrapur
# City not found. Skipping...
# Processing Record 49 of Set 12 | iron river
# City not found. Skipping...
# Processing Record 0 of Set 13 | el tigre
# City not found. Skipping...
# Processing Record 1 of Set 13 | morehead city
# City not found. Skipping...
# Processing Record 2 of Set 13 | meadow lakes
# City not found. Skipping...
# Processing Record 3 of Set 13 | solwezi
# City not found. Skipping...
# Processing Record 4 of Set 13 | eenhana
# Processing Record 5 of Set 13 | wynyard
# Processing Record 6 of Set 13 | howard springs
# Processing Record 7 of Set 13 | yoloten
# Processing Record 8 of Set 13 | sherwood park
# Processing Record 9 of Set 13 | kachug
# Processing Record 10 of Set 13 | san luis de la loma
# Processing Record 11 of Set 13 | rio preto da eva
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# Convert the city_data list to a DataFrame
city_data_df = pd.DataFrame(city_data)

# Show the record count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display city_data
city_data_df
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                   tura  25.5198   90.2201     21.18        57           0
# 1                  altai  46.3722   96.2583      0.71        24          98
# 2                  sitka  57.0531 -135.3300      3.94        81         100
# 3              grytviken -54.2811  -36.5092      2.19        93          61
# 4                iqaluit  63.7506  -68.5145      0.85        93         100
# ..                   ...      ...       ...       ...       ...         ...
# 574              yoloten  37.2989   62.3597     24.32        22          50
# 575        sherwood park  53.5168 -113.3187     14.84        43          75
# 576               kachug  53.9606  105.8817     -4.25        84          94
# 577  san luis de la loma  17.2706 -100.8939     29.78        62          84
# 578     rio preto da eva  -2.6994  -59.6997     27.19        81          98
#
#      Wind Speed Country        Date
# 0          1.61      IN  1682368670
# 1          1.51      MN  1682368991
# 2          5.14      US  1682368767
# 3          5.52      GS  1682368665
# 4          2.57      CA  1682368688
# ..          ...     ...         ...
# 574        5.97      TM  1682369165
# 575        3.13      CA  1682369266
# 576        0.95      RU  1682369267
# 577        4.12      MX  1682368750
# 578        1.02      BR  1682369267
#
# [579 rows x 9 columns]

# %%
city_data_df.to_csv("output_data/cities.csv", index = False)

# %%
import matplotlib.pyplot as plt

# Extract data for latitude and max temperature from city_data list
latitudes = [city['Lat'] for city in city_data]
max_temps = [city['Max Temp'] for city in city_data]

# Build scatter plot
plt.scatter(latitudes, max_temps, marker='o', edgecolors='black')

# Set plot title and labels
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Set grid
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Max Temperature.png")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract data for latitude and humidity from city_data list
latitudes = [city['Lat'] for city in city_data]
humidities = [city['Humidity'] for city in city_data]

# Build scatter plot
plt.scatter(latitudes, humidities, marker='o', edgecolors='black')

# Set plot title and labels
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Set grid
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Humidity.png")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract data for latitude and cloudiness from city_data list
latitudes = [city['Lat'] for city in city_data]
cloudiness = [city['Cloudiness'] for city in city_data]

# Build scatter plot
plt.scatter(latitudes, cloudiness, marker='o', edgecolors='black')

# Set plot title and labels
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Set grid
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract data for latitude and wind speed from city_data list
latitudes = [city['Lat'] for city in city_data]
wind_speeds = [city['Wind Speed'] for city in city_data]

# Build scatter plot
plt.scatter(latitudes, wind_speeds, marker='o', edgecolors='black')

# Set plot title and labels
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Set grid
plt.grid(True)

# Save the figure
plt.savefig("output_data/City Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress, pearsonr

def linear_regression(x, y, xlabel, ylabel, title):
    
    # Calculate linear regression
    try:
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
    except ValueError:
        print("Linear regression failed.")
        return None
    
    # Create regression line
    regression_line = slope * x + intercept
    
    # Create scatter plot
    plt.scatter(x, y)
    
    # Plot regression line
    plt.plot(x, regression_line, color='red')
    
    # Annotate regression equation
    plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (np.max(x), np.max(y)), fontsize=12, color='red', ha='right')
    
    # Set labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Calculate R-squared
    r_squared = pearsonr(x, y)[0] ** 2
    
    # Print R-squared
    print(f"The R-squared value is: {round(r_squared, 2)}")
    
    # Show plot
    plt.show()
    
    # Return the calculated values
    return slope, intercept, r_value, p_value, std_err

# %%
# Filter rows with Latitude >= 0 to create Northern Hemisphere DataFrame
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     tura  25.5198   90.2201     21.18        57           0        1.61
# 1    altai  46.3722   96.2583      0.71        24          98        1.51
# 2    sitka  57.0531 -135.3300      3.94        81         100        5.14
# 4  iqaluit  63.7506  -68.5145      0.85        93         100        2.57
# 5     mili   6.0815  171.7350     28.05        81          97        8.89
#
#   Country        Date
# 0      IN  1682368670
# 1      MN  1682368991
# 2      US  1682368767
# 4      CA  1682368688
# 5      MH  1682368689

# %%
# Filter rows with Latitude <= 0 to create Southern Hemisphere DataFrame
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3       grytviken -54.2811  -36.5092      2.19        93          61
# 8    port lincoln -34.7333  135.8667     18.37        56          49
# 9    punta arenas -53.1500  -70.9167      7.06        93         100
# 13  blackmans bay -43.0167  147.3167     10.39        89         100
# 16    west island -12.1568   96.8225     26.99        74         100
#
#     Wind Speed Country        Date
# 3         5.52      GS  1682368665
# 8         2.66      AU  1682368422
# 9         3.60      CL  1682368690
# 13        2.56      AU  1682368666
# 16        9.77      CC  1682368684

# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

def linear_regression(x, y, xlabel, ylabel, title, filename):
    
    #Calculate linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    
    #Create regression line
    regression_line = slope * x + intercept
    
    #Add the R-value to the plot
    plt.text(0.05, 0.95, f"The r-value is: {round(r_value, 4)}", transform=plt.gca().transAxes, ha='left', va='top')
    
    #Create scatter plot
    plt.scatter(x, y)
    
    plt.plot(x,regression_line,"r-")
    
    # Plot regression line
    plt.plot(x, regression_line, color='red')
    
    # Annotate regression equation
    plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (np.max(x), np.max(y)), fontsize=12, color='red', ha='right')
    
    # Set labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Save plot to file
    plt.savefig(filename)
    
    # Show plot
    plt.show()

# %%
# Define output filename
north_hem_fig_1 = 'output_data/Northern Hemisphere - Max_Temp_vs_Latitude_linear_regression_northern_hemi.png'

# %%
# Extract x and y values from the Northern Hemisphere DataFrame
x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Max Temperature (C)', 'Northern Hemisphere - Max Temp vs Latitude Linear Regression', north_hem_fig_1)

# %%
#Define output filename
south_hem_fig_1 = 'output_data/Southern Hemisphere Max_Temp_vs_Latitude_linear_regression_southern_hemi.png'

# %%
# Extract x and y values from the Southern Hemisphere DataFrame
x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']

# Create linear regression plot and save to file
linear_regression(x, y, 'Latitude', 'Max Temperature (C)', 'Southern Hemisphere - Max Temp vs Latitude Linear Regression', south_hem_fig_1)

# %%
# Define output filename
north_hem_fig_2 = 'output_data/Northern Hemisphere - Humidity(%) vs Latitude Linear Regression_north_hem_fig_humidity.png'

# %%
# Extract x and y values from the Northern Hemisphere DataFrame
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Humidity (%)', 'Northern Hemisphere - Humidity(%) vs Latitude Linear Regression',north_hem_fig_2)

# %%
# Define output filename
south_hem_fig_2 = 'output_data/Southern Hemisphere - Humidity(%) vs Latitude Linear Regression_south_hem_fig_humidity.png'

# %%
# Extract x and y values from the Southern Hemisphere DataFrame
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Humidity (%)', 'Southern Hemisphere - Humidity(%) vs Latitude Linear Regression',south_hem_fig_2)

# %%
# Define output filename
north_hem_fig_3 = 'output_data/Northern Hemisphere - Cloudiness vs Latitude Linear Regression_north_hem_fig_cloudiness.png'

# %%
# Extract x and y values from the Northern Hemisphere DataFrame
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Cloudiness', 'Northern Hemisphere - Cloudiness vs Latitude Linear Regression', north_hem_fig_3)

# %%
# Define output filename
south_hem_fig_3 = 'output_data/Southern Hemisphere - Cloudiness vs Latitude Linear Regression_south_hem_fig_cloudiness.png'

# %%
# Extract x and y values from the Southern Hemisphere DataFrame
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Cloudiness', 'Southern Hemisphere - Cloudiness vs Latitude Linear Regression', south_hem_fig_3)

# %%
# Define output filename
north_hem_fig_4 = 'output_data/Northern Hemisphere - Wind Speed vs Latitude Linear Regression_north_hem_fig_windspeed.png'

# %%
# Extract x and y values from the Northern Hemisphere DataFrame
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Wind Speed', 'Northern Hemisphere - Wind Speed vs Latitude Linear Regression', north_hem_fig_4)

# %%
# Define output filename
south_hem_fig_4 = 'output_data/Southern Hemisphere - Wind Speed vs Latitude Linear Regression_south_hem_fig_windspeed.png'

# %%
# Extract x and y values from the Southern Hemisphere DataFrame
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']

# Call linear_regression() with the desired filename
linear_regression(x, y, 'Latitude', 'Wind Speed', 'Southern Hemisphere - Wind Speed vs Latitude Linear Regression', south_hem_fig_4)
